# %% [markdown]
# <center><h3> News Tweet Analysis </h3>
# Sita Robinson, Nick Santini, Abdelrahman Salem</center>

# %% [markdown]
# We saved 4001 tweets using the tweepy streaming api into a mongo db database from May 25th, 2019.

# %% [markdown]
# Goals:
# * What hour of the day was the most/least tweets posted?
# * What topics go under the categories of positive, negative, and neutral sentiments?
# * What topics do people talk about most?

# %% [markdown]
# Completed
# * Saved data into mongodb (4001 tweets)-Sita
# * Tweet activity over time-Sita
# * Sentiment Analysis Polarity Scores-Nick, Sita
# * Histogram of Sentiments-Sita
# * Word Clouds for positive, negative, overall-Sita
# * Unigram Frequency Counter-Nick
# * Bigram Frequency Counter-Nick
# * Bigram barchart-Nick
#
# In Progress
# * LDA-Sita
# * PyLDAvis plot-Sita

# %% [markdown]
# TODO:
# * Cosine similarity matrix
# * TF-IDF matrix

# %% [markdown]
# Didn't make sense to do a map because there was a lot of junk in the location data.

# %%
host = 'mongodb+srv://sita-readonly:readonly@cluster0-lhmfm.mongodb.net/test?retryWrites=true'

# %%
import twitter
import json
import tweepy
import pandas as pd
import numpy as np
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
import re
from sklearn.feature_extraction.text import CountVectorizer
import scipy as sp
import pymongo
import sklearn.decomposition as dec

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /usr/local/share/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
def load_from_mongo(mongo_db, mongo_db_coll, return_cursor=False,
                    criteria=None, projection=None, **mongo_conn_kw):
    
    client = pymongo.MongoClient(**mongo_conn_kw)
    db = client[mongo_db]
    coll = db[mongo_db_coll]
    
    if criteria is None:
        criteria = {}
    
    if projection is None:
        cursor = coll.find(criteria)
    else:
        cursor = coll.find(criteria, projection)

    # Returning a cursor is recommended for large amounts of data
    if return_cursor:
        return cursor
    else:
        return [ item for item in cursor ]

# %% [markdown]
# Loading data from mongodb.

# %%
cached_tweets = load_from_mongo('search_results', 'news_stream', host=host)

# %%
cached_tweets[0]['text']
# Out:
# 'Sound at Spice Girls Dublin gig-a-big-nah - https://t.co/9rmHhmdgHX #news #allworldnews.top https://t.co/6Ahd5hl1GT'

# %% [markdown]
# Saving tweets into data frame.

# %%
data = pd.DataFrame(data=[tweet['text'] for tweet in cached_tweets], columns=['Tweets'])

# %%
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# Checking first 10 tweets in dataframe.

# %%
data.head(10)
# Out:
#                                                                                                                                       Tweets
# 0  Sound at Spice Girls Dublin gig-a-big-nah - https://t.co/9rmHhmdgHX #news #allworldnews.top https://t.co/6Ahd5hl1GT
# 1  https://t.co/1MwaU3Ceul: Which public US universities graduate the most funded founders? https://t.co/4x3DWCgOc5… https://t.co/BpCwu2PS6t
# 2  Flights resume after Bali volcano disruption - https://t.co/ArPTCSDwKD #news #allworldnews.top https://t.co/kEUvK6R8B7
# 3  Eagle boosts Blixt to Colonial lead, Finau and Na one back - https://t.co/yyC7OI8KhK\n\n #News https://t.co/FEBSx3cd0L
# 4  Infrastructure talks on hold as feud between President Trump and Democrats intensifies - https://t.co/eVWaonOQJJ #news #allworldnews.top
# 5  Mississippi man finds huge alligator snapping turtle, sets county record - https://t.co/H27HVT9VCF #news #allworldnews.top
# 6  #Obama #Attacks on #Press #Spying worse than thought! #FOX \n#NEWS link at https://t.co/hLLSkgKB7f https://t.co/h3GvDsKPfz
# 7  Soldier seen placing flag at Tomb of Unknown Soldier during torrential rain - https://t.co/oowk56poNq #news #allworldnews.top
# 8  GOP lawmaker’s delay of $19 billion disaster bill demonstrates the power of one - https://t.co/wG17WOcfbl #news #allworldnews.top
# 9  VP Pence gives commencement address at US Military Academy - https://t.co/8zVbnhy6P7 #news #allworldnews.top

# %% [markdown]
# Making sure there are 4001 rows.

# %%
len(data)
# Out:
# 4001

# %% [markdown]
# <center><h3>Tweet Activity over Time</h3></center>

# %%
date=pd.DataFrame(data=[tweet['created_at'] for tweet in cached_tweets], columns=['Created'])

# %%
date=pd.DataFrame(pd.to_datetime(date.Created))

# %% [markdown]
# Since all the data comes from May 25th, we will just look at hours.

# %%
datefixed=date['Created'].apply(lambda t: t.strftime('%H'))

# %%
datecounts=pd.DataFrame(datefixed.value_counts(sort=False), columns=['Created']).sort_index()
datecounts
# Out:
#     Created
# 16  698
# 17  752
# 18  605
# 19  656
# 20  564
# 21  502
# 22  224

# %%
datecounts.plot(figsize=(20,10), color=['#cf9d85'], legend=False, linewidth=2.5)
plt.title("Number of Tweets Made on May 25th by Hour", fontsize="15")
plt.xlabel("Time (Hour)", fontsize="14")
plt.ylabel("Number of Tweets", fontsize="14")
plt.xticks(rotation=0)
plt.grid()   
plt.show()

# %% [markdown]
# Tweets collected were from 4pm-10pm.  The least number of tweets was from hour 22 or 10pm and the most number of tweets was from hour 17 or 5pm.

# %% [markdown]
# <center><h3>Sentiment Analysis</h3></center>

# %%
sid = SentimentIntensityAnalyzer()
storagepos = []
storageneg = []
storageneu = []
storagecomp=[]
for index, row in data.iterrows():
    ng = sid.polarity_scores(row["Tweets"])['neg']
    storageneg.append(ng)
    pos = sid.polarity_scores(row["Tweets"])['pos']
    storagepos.append(pos)
    neu = sid.polarity_scores(row["Tweets"])['neu']
    storageneu.append(neu)
    cp = sid.polarity_scores(row["Tweets"])['compound']
    storagecomp.append(cp)

negstorage = pd.Series(storageneg)
data['neg polarity'] = negstorage.values
posstorage = pd.Series(storagepos)
data['pos polarity'] = posstorage.values 
neustorage = pd.Series(storageneu)
data['neu polarity'] = neustorage.values
compstorage = pd.Series(storagecomp)
data['compound'] = compstorage.values

display(data.head(20))
# Out:
#                                                                                                                                            Tweets  \
# 0   Sound at Spice Girls Dublin gig-a-big-nah - https://t.co/9rmHhmdgHX #news #allworldnews.top https://t.co/6Ahd5hl1GT
# 1   https://t.co/1MwaU3Ceul: Which public US universities graduate the most funded founders? https://t.co/4x3DWCgOc5… https://t.co/BpCwu2PS6t
# 2   Flights resume after Bali volcano disruption - https://t.co/ArPTCSDwKD #news #allworldnews.top https://t.co/kEUvK6R8B7
# 3   Eagle boosts Blixt to Colonial lead, Finau and Na one back - https://t.co/yyC7OI8KhK\n\n #News https://t.co/FEBSx3cd0L
# 4   Infrastructure talks on hold as feud between President Trump and Democrats intensifies - https://t.co/eVWaonOQJJ #news #allworldnews.top
# 5   Mississippi man finds huge alligator snapping turtle, sets county record - https://t.co/H27HVT9VCF #news #allworldnews.top
# 6   #Obama #Attacks on #Press #Spying worse than thought! #FOX \n#NEWS link at https://t.co/hLLSkgKB7f https://t.co/h3GvDsKPfz
# 7   Soldier seen placing flag at Tomb of Unknown Soldier during torrential rain - https://t.co/oowk56poNq #news #allworldnews.top
# 8   GOP lawmaker’s delay of $19 billion disaster bill demonstrates the power of one - https://t.co/wG17WOcfbl #news #allworldnews.top
# 9   VP Pence gives commencement address at US Military Academy - https://t.co/8zVbnhy6P7 #news #allworldnews.top
# 10  Hatchet-wielding thief backs down when store clerk pulls out gun - but firearm costs employee his job -… https://t.co/d4D2Nqknak
# 11  Flexible TV Display\n\n#Electronics #Music #Nano #Video #AI #Education #News #Leadership #Technology #Nanotechnology… https://t.co/1wtLroPTCi
# 12  What does Memorial Day mean to military service members? - https://t.co/kzayUviNmk #news #allworldnews.top
# 13  Kanye West explains what it is like to get criticized as a Trump supporter - https://t.co/B13jJ7BNnL #news #allworldnews.top
# 14  'Fox &amp; Friends' annual BBQ Bash! - https://t.co/cwkmAqgXYI #news #allworldnews.top
# 15  Feminist author Naomi Wolf admits error in new book after called out live on air for misunderstanding data -… https://t.co/OFkUoKdGCd
# 16  #realestate #news #updates @nytrealestate Living In ... Orange, Conn. https://t.co/FJXQcYxBIv
# 17  This Is What It Sounds Like When Brands Cry https://t.co/ZhTOsY5t79 #wuwei #today #best #news #daily #feed
# 18  #btsv #news #love #fail #funny For More Memes https://t.co/3bEIE69OVJ https://t.co/qdyh3ZRhmC
# 19  St Peters Street now! May 25, 2019 at 05:15PM #StAlbans #traffic #travel #weather #news #update https://t.co/yDKA9pP6L5
#
#     neg polarity  pos polarity  neu polarity  compound
# 0   0.000         0.000         1.000         0.0000
# 1   0.000         0.000         1.000         0.0000
# 2   0.217         0.000         0.783        -0.3612
# 3   0.000         0.150         0.850         0.3182
# 4   0.146         0.000         0.854        -0.3400
# 5   0.000         0.161         0.839         0.3182
# 6   0.207         0.000         0.793        -0.5255
# 7   0.000         0.000         1.000         0.0000
# 8   0.314         0.000         0.686        -0.7506
# 9   0.000         0.000         1.000         0.0000
# 10  0.250         0.000         0.750        -0.4588
# 11  0.000         0.128         0.872         0.2263
# 12  0.000         0.000         1.000         0.0000
# 13  0.124         0.229         0.647         0.2732
# 14  0.000         0.298         0.702         0.5255
# 15  0.223         0.089         0.688        -0.5106
# 16  0.000         0.000         1.000         0.0000
# 17  0.158         0.128         0.714        -0.1531
# 18  0.000         0.000         1.000         0.0000
# 19  0.000         0.000         1.000         0.0000

# %% [markdown]
# <center><h4> Histogram of Sentiments</h4></center>

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot histogram of the polarity values
data['compound'].hist(bins=[-1, -0.75, -0.5, -0.25, 0.25, 0.5, 0.75, 1],
             ax=ax,
             color=['#cf9d85'])

plt.title("Histogram of Sentiments in News Tweets")
plt.show()

# %% [markdown]
# Looking at this histogram there seems to be in general more neutral and positive sentement in tweets than negative.

# %% [markdown]
# <center><h3> What topics go under negative, positive, and neutral sentiments?</h3></center>

# %% [markdown]
# <center><h4> Unigram Analysis</h4></center>

# %% [markdown]
# Unigram Frequency Counter

# %%
from nltk.corpus import stopwords
import nltk, re, string, collections
from nltk.util import ngrams
set(stopwords.words('english'))

BigramText = ""
counter = 0
for item in cached_tweets:
    BigramText = BigramText + cached_tweets[counter]['text']
    counter += 1

#Get rid of unwanted characters
for letter in '@#!?.0123456789,':
    BigramText = BigramText.replace(letter,'')

#print(PhiladelphiaBigramText)

word_list = BigramText.split()
#Get rid of stop words
filtered_words = [word for word in word_list if word not in stopwords.words('english')]
BigramText = " ".join(filtered_words)

#Show top 10 bigrams by frequency
word_list = BigramText.split()
esBigrams = ngrams(word_list,1)
esBigramFreq = collections.Counter(esBigrams)
esBigramFreq.most_common(200)
# Out:
# [(('news',), 1088),
#  (('News',), 780),
#  (('-',), 657),
#  (('business',), 344),
#  (('The',), 305),
#  (('design',), 297),
#  (('logo',), 294),
#  (('brand',), 292),
#  (('minimalist',), 291),
#  (('website',), 239),
#  (('latest',), 217),
#  (('Startup',), 178),
#  (('https://tco/tnOBqHoH',), 166),
#  (('Thanks',), 158),
#  (('TheBossLogo',), 154),
#  (('Business…',), 143),
#  (('New',), 142),
#  (('&amp;',), 140),
#  (('Daily',), 130),
#  (('|',), 124),
#  (('Trump',), 123),
#  ((':',), 115),
#  (('A',), 113),
#  (('via',), 110),
#  (('For',), 103),
#  (('More:',), 101),
#  (('MLB',), 97),
#  (('DFS',), 93),
#  (('To',), 90),
#  (('VİDEO',), 88),
#  (('🎥:',), 88),
#  (('World',), 86),
#  (('May',), 85),
#  (('News:',), 83),
#  (('Music',), 77),
#  (('new',), 75),
#  (('More',), 71),
#  (('$',), 68),
#  (('news…',), 68),
#  (('US',), 65),
#  (('https://tco/tnOBqHoH…',), 65),
#  (('-…',), 63),
#  (('Is',), 63),
#  (('In',), 62),
#  (('bestkadin',), 62),
#  (('NEWS',), 59),
#  (('tech',), 59),
#  (('viral',), 59),
#  (('%',), 59),
#  (('Of',), 54),
#  (('blog',), 54),
#  (('website…',), 53),
#  (('And',), 52),
#  (('news:',), 52),
#  (('today',), 51),
#  (('best',), 51),
#  (('News…',), 51),
#  (('says',), 49),
#  (('like',), 45),
#  (('With',), 45),
#  (('politics',), 44),
#  (('Times',), 43),
#  (('–',), 43),
#  (('News":',), 43),
#  (('On',), 43),
#  (('love',), 42),
#  (('From',), 42),
#  (('Get',), 42),
#  (('funny',), 41),
#  (('Todau',), 41),
#  (('blogger',), 41),
#  (('I',), 41),
#  (('This',), 40),
#  (('k',), 40),
#  (('video',), 39),
#  (('PM',), 39),
#  (('…',), 38),
#  (('Bitcoin',), 38),
#  (('Day',), 37),
#  (('get',), 37),
#  (('two',), 37),
#  (('If',), 36),
#  (('allworldnewstop📌',), 36),
#  (('President',), 35),
#  (('one',), 34),
#  (('first',), 34),
#  (('people',), 34),
#  (('Nigeria',), 34),
#  (('Read',), 33),
#  (('~',), 33),
#  (('What',), 32),
#  (('travel',), 32),
#  (('share',), 32),
#  (('Pelosi',), 32),
#  (('Career',), 32),
#  (('Are',), 31),
#  (('music',), 31),
#  (('India',), 31),
#  (('You',), 30),
#  (('RT',), 30),
#  ((':PM',), 29),
#  (('time',), 29),
#  (('Saturday',), 29),
#  (('"',), 29),
#  (('daily',), 28),
#  (('UK',), 28),
#  (('Baby',), 28),
#  (('beautiful',), 28),
#  (('We',), 28),
#  (('Says',), 28),
#  (('every',), 28),
#  (('fail',), 27),
#  (('war',), 27),
#  (('Russia',), 27),
#  (('Your',), 27),
#  (('Reviews',), 27),
#  (('Will',), 27),
#  (('Startup…',), 27),
#  (('Cannes',), 27),
#  (('Video',), 26),
#  (('wuwei',), 26),
#  (('Memes',), 26),
#  (('Japan',), 26),
#  (('cars',), 26),
#  (('+',), 26),
#  (('Shower',), 26),
#  (('Why',), 26),
#  (('good',), 26),
#  (('auspol',), 26),
#  (('Nissan',), 26),
#  (('great',), 26),
#  (('jobsearch',), 26),
#  (('Join',), 25),
#  (('TeamBossyGals➽',), 25),
#  (("'GOD'",), 25),
#  (('reviews',), 25),
#  (('USA',), 25),
#  (('Market',), 25),
#  (('th',), 25),
#  (('Facebook',), 25),
#  (('After',), 25),
#  (('United',), 25),
#  (('https://tco/bEIEOVJ',), 24),
#  (('newsThe',), 24),
#  (('Libya',), 24),
#  (('All',), 24),
#  (('technology',), 24),
#  (('First',), 24),
#  (('clintonkowach',), 24),
#  (('It',), 23),
#  (('health',), 23),
#  (('us',), 23),
#  (('breakingnews',), 23),
#  (('SoccerNews',), 23),
#  (('Now',), 23),
#  (('could',), 23),
#  (('That',), 23),
#  (('Up',), 23),
#  (('NEWS:',), 23),
#  (('japan',), 23),
#  (('city',), 22),
#  (('About',), 22),
#  (('Travel',), 22),
#  (('Greece',), 22),
#  (('day',), 22),
#  (('Live',), 22),
#  (('Have',), 22),
#  (('Twitter',), 22),
#  (('japanese',), 22),
#  (('back',), 21),
#  (('trade',), 21),
#  (('next',), 21),
#  (('soccer',), 21),
#  (('sports',), 21),
#  (('actual',), 21),
#  (('By',), 21),
#  (('Price',), 21),
#  (('Radar',), 21),
#  (('West',), 20),
#  (('trending',), 20),
#  (('breaking',), 20),
#  (('—',), 20),
#  (('blockchain',), 20),
#  (('logistics',), 20),
#  (('bitcoin',), 20),
#  (('WATCH',), 20),
#  (('live',), 19),
#  (('know',), 19),
#  (('see',), 19),
#  (('money',), 19),
#  (('South',), 19),
#  (('(via',), 19),
#  (('world',), 19),
#  (('Crypto',), 19),
#  (('As',), 19),
#  (('Review',), 19),
#  (('Tech',), 19),
#  (('Book',), 19),
#  (('Hail',), 19),
#  (('mph',), 19)]

# %% [markdown]
# Word Clouds

# %%
pos = data[data['compound']> 0.5]
pos = pos['Tweets']
neg = data[data['compound']< -0.5]
neg = neg['Tweets']
def wordcloud_draw(data):
    words = ' '.join(data)
    cleaned_word = " ".join([word.lower() for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT' 
                            ])
    wordcloud = WordCloud(stopwords=STOPWORDS,
                      background_color='white',
                      width=2500,
                      height=2000,
                      collocations=False
                     ).generate(cleaned_word)
    plt.figure(1,figsize=(13, 13))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
print("Positive words")
wordcloud_draw(pos)
print("Negative words")
wordcloud_draw(neg)
print("Overall wordcloud")
wordcloud_draw(data['Tweets'])
# Out:
# Positive words
# Negative words
# Overall wordcloud

# %% [markdown]
# The data was divided up into positive and negative based on tweets with a compound polarity value greater than 0.5 and less than 0.5 respectively.  The overall wordcloud seems to show more of the neutral words with a focus on business related news.  The negative wordcloud shows words such as war, death, kill, ban.  The postitive wordcloud shows terms such as join,win,share,united, festival, career.  These values seem to correlate to what we think of as positive and negative terms.

# %% [markdown]
# <center><h4> Bigram Analysis</h4></center>

# %%
from nltk.corpus import stopwords
import nltk, re, string, collections
from nltk.util import ngrams
set(stopwords.words('english'))

BigramText = ""
counter = 0
for item in cached_tweets:
    BigramText = BigramText + cached_tweets[counter]['text']
    counter += 1

#Get rid of unwanted characters
for letter in '@#!?.0123456789,':
    BigramText = BigramText.replace(letter,'')

#print(PhiladelphiaBigramText)

word_list = BigramText.split()
#Get rid of stop words
filtered_words = [word for word in word_list if word not in stopwords.words('english')]
BigramText = " ".join(filtered_words)

#Show top 10 bigrams by frequency
word_list = BigramText.split()
esBigrams = ngrams(word_list,2)
esBigramFreq = collections.Counter(esBigrams)
esBigramFreq.most_common(20)
# Out:
# [(('minimalist', 'logo'), 291),
#  (('logo', 'design'), 291),
#  (('design', 'business'), 289),
#  (('business', 'brand'), 288),
#  (('brand', 'website'), 233),
#  (('website', 'https://tco/tnOBqHoH'), 166),
#  (('TheBossLogo', 'minimalist'), 150),
#  (('Startup', 'Business…'), 141),
#  (('https://tco/tnOBqHoH', 'Startup'), 139),
#  (('latest', 'The'), 97),
#  (('DFS', 'MLB'), 93),
#  (('New', 'VİDEO'), 88),
#  (('VİDEO', '🎥:'), 88),
#  (('MLB', 'News'), 85),
#  (('website', 'https://tco/tnOBqHoH…'), 65),
#  (('brand', 'website…'), 52),
#  (('news', 'bestkadin'), 44),
#  (('viral', 'news'), 42),
#  (('Todau', 'News'), 41),
#  (('News', 'World'), 41)]

# %%
import matplotlib.pyplot as plt
import numpy as np

#Only care about frequency greator than 1
label = ['minimalist logo','logo design','business brand','brand website', 'TheBossLogo minimalist']
frequencies = [291,291,289,288,233]
index = np.arange(len(label))

print(esBigramFreq.most_common(5))

def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(label))
    plt.bar(index, frequencies)
    plt.xlabel('Frequency in Token Set', fontsize=5)
    plt.ylabel('# of Occurances', fontsize=5)
    plt.xticks(index, label, fontsize=5, rotation=30)
    plt.title('Top 5 Bigram Occurance Count')
    plt.show()

plot_bar_x()
# Out:
# [(('minimalist', 'logo'), 291), (('logo', 'design'), 291), (('design', 'business'), 289), (('business', 'brand'), 288), (('brand', 'website'), 233)]

# %% [markdown]
# <center><h4> TF-IDF Matrix </h4></center>

# %%
#TODO

# %% [markdown]
# <center><h3>Latent Dirichlet Allocation (LDA)-What topics are people tweeting about?</h3></center>

# %%
cltweets = [t.lower() for t in data['Tweets']]
cltweets = [re.sub(r'http\S*', ' ', t) for t in cltweets]
cltweets = [re.sub(r'\srt\s', ' ', t) for t in cltweets]
cltweets = [re.sub(r'^rt\s', ' ', t) for t in cltweets]
cltweets = [re.sub(r'\srt$', ' ', t) for t in cltweets]
cltweets = [re.sub(r'@\S+', '', t) for t in cltweets]
cltweets = [re.sub(r'#\S+', '', t) for t in cltweets]

# %%
count = CountVectorizer(stop_words='english', max_df=0.98, min_df=0.01)
df_bag = count.fit_transform(cltweets)
feature_names = count.get_feature_names()

feature_wts = sp.sparse.csr_matrix.sum(df_bag, axis=0)
feature_wts = np.array(feature_wts).flatten()

n_top_words = 50
print(" ".join([feature_names[i] for i in feature_wts.argsort()[:-n_top_words - 1:-1]]))
# Out:
# business design thebosslogo brand logo minimalist website new news latest 2019 thanks amp trump daily vi deo says day video world watch bitcoin president 25 music 10 like live gt time best times read pm people join just great year god click

# %%
lda = dec.LatentDirichletAllocation(n_components=9)
lda.fit(df_bag)
n_top_words = 10
for topic_idx, topic in enumerate(lda.components_):
        print("Topic %d: " % topic_idx, end='')
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))
# Out:
# C:\Users\sitar\Anaconda3\Anaconda3NEW\lib\site-packages\sklearn\decomposition\online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# Topic 0: trump people like president click just video says 10 times
# Topic 1: 2019 25 read just time times latest new click thanks
# Topic 2: latest thanks daily news read times watch amp gt world
# Topic 3: new watch 10 gt pm live click 2019 25 deo
# Topic 4: business design brand thebosslogo logo website minimalist 10 latest click
# Topic 5: world video day best year join god like 2019 news
# Topic 6: says music president bitcoin like gt new read trump video
# Topic 7: news amp president trump world pm watch design click people
# Topic 8: vi deo bitcoin great daily new business news latest amp

# %% [markdown]
# <center><h4> PyLDAvis plot</h4></center>

# %% [markdown]
# https://nbviewer.jupyter.org/github/bmabey/hacker_news_topic_modelling/blob/master/HN%20Topic%20Model%20Talk.ipynb
# https://pyldavis.readthedocs.io/en/latest/readme.html

# %%
from gensim import corpora, models
import pyLDAvis.gensim
# Out:
# C:\Users\sitar\Anaconda3\Anaconda3NEW\lib\site-packages\boto\__init__.py:1142: DeprecationWarning: invalid escape sequence \c
#   """
# C:\Users\sitar\Anaconda3\Anaconda3NEW\lib\site-packages\boto\pyami\config.py:98: DeprecationWarning: invalid escape sequence \s
#   match = re.match("^#import[\s\t]*([^\s^\t]*)[\s\t]*$", line)
# C:\Users\sitar\Anaconda3\Anaconda3NEW\lib\site-packages\scipy\sparse\sparsetools.py:20: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
